# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib

# %%
# Import Dependencies
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
# from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder,MinMaxScaler

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
# Check the information of the DataFrame
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
# Convert all of the rows to float64 to get the same type for all cells
for column,cell in df.items():
    if df[column].dtype=='int64':
        df=df.astype({column:'float64'})

# %%
# Double check the info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6991 entries, 0 to 6990
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   koi_disposition    6991 non-null   object
#  1   koi_fpflag_nt      6991 non-null   float64
#  2   koi_fpflag_ss      6991 non-null   float64
#  3   koi_fpflag_co      6991 non-null   float64
#  4   koi_fpflag_ec      6991 non-null   float64
#  5   koi_period         6991 non-null   float64
#  6   koi_period_err1    6991 non-null   float64
#  7   koi_period_err2    6991 non-null   float64
#  8   koi_time0bk        6991 non-null   float64
#  9   koi_time0bk_err1   6991 non-null   float64
#  10  koi_time0bk_err2   6991 non-null   float64
#  11  koi_impact         6991 non-null   float64
#  12  koi_impact_err1    6991 non-null   float64
#  13  koi_impact_err2    6991 non-null   float64
#  14  koi_duration       6991 non-null   float64
# ...

# %%
# Check the unique values in koi_disposition column
df['koi_disposition'].unique()
# Out:
# array(['CONFIRMED', 'FALSE POSITIVE', 'CANDIDATE'], dtype=object)

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
X = df.drop('koi_disposition',axis=1)
y=df['koi_disposition']
print(X.shape,y.shape)
# Out:
# (6991, 40) (6991,)

# %% [markdown]
# # Convert the koi_disposition to numerical values

# %%
# Convert the string to numerical value
# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y)
encoded_y = label_encoder.transform(y)

# %%
for label, original_class in zip(encoded_y, y):
    print('Original Class: ' + str(original_class))
    print('Encoded Label: ' + str(label))
    print('-' * 12)
# Out:
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: FALSE POSITIVE
# Encoded Label: 2
# ------------
# Original Class: FALSE POSITIVE
# Encoded Label: 2
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: FALSE POSITIVE
# Encoded Label: 2
# ------------
# Original Class: FALSE POSITIVE
# Encoded Label: 2
# ------------
# Original Class: FALSE POSITIVE
# Encoded Label: 2
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# ...

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
# Create the Train_Test_Split 
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.5, random_state=42)

# %%
# Display the training set
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 3021            0.0            0.0            0.0            0.0    1.450890
# 1972            0.0            0.0            0.0            0.0   11.191620
# 1714            0.0            0.0            0.0            0.0    6.739683
# 4480            1.0            0.0            0.0            0.0  310.612990
# 5255            1.0            0.0            1.0            0.0    1.247121
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 3021         0.000006        -0.000006    132.23060           0.00325
# 1972         0.000081        -0.000081    138.04258           0.00600
# 1714         0.000064        -0.000064    132.29296           0.00816
# 4480         0.010220        -0.010220    267.04510           0.03350
# 5255         0.000005        -0.000005    132.39461           0.00196
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# We want to scale our data down to a simple numerical range. We do not want to have a big range, cause the ML will work better 
# with one range of data. In this case, I use the MinMaxScaler to scale out the X values
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# %%
# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# %%
# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=40))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=3, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 100)               4100
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 303
# ...
# Total params: 14,503
# Trainable params: 14,503
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 110/110 - 0s - loss: 0.6146 - accuracy: 0.7050
# Epoch 2/100
# 110/110 - 0s - loss: 0.3672 - accuracy: 0.8177
# Epoch 3/100
# 110/110 - 0s - loss: 0.3451 - accuracy: 0.8266
# Epoch 4/100
# 110/110 - 0s - loss: 0.3391 - accuracy: 0.8240
# Epoch 5/100
# 110/110 - 0s - loss: 0.3341 - accuracy: 0.8303
# Epoch 6/100
# 110/110 - 0s - loss: 0.3179 - accuracy: 0.8498
# Epoch 7/100
# 110/110 - 0s - loss: 0.3131 - accuracy: 0.8466
# Epoch 8/100
# 110/110 - 0s - loss: 0.3136 - accuracy: 0.8452
# Epoch 9/100
# 110/110 - 0s - loss: 0.3155 - accuracy: 0.8495
# Epoch 10/100
# 110/110 - 0s - loss: 0.3023 - accuracy: 0.8598
# Epoch 11/100
# 110/110 - 0s - loss: 0.2972 - accuracy: 0.8672
# Epoch 12/100
# 110/110 - 0s - loss: 0.2958 - accuracy: 0.8638
# Epoch 13/100
# 110/110 - 0s - loss: 0.2967 - accuracy: 0.8581
# Epoch 14/100
# 110/110 - 0s - loss: 0.2940 - accuracy: 0.8618
# Epoch 15/100
# 110/110 - 0s - loss: 0.2891 - accuracy: 0.8695
# Epoch 16/100
# ...

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 110/110 - 0s - loss: 0.3012 - accuracy: 0.8833
# Normal Neural Network - Loss: 0.3011941909790039, Accuracy: 0.8832951784133911

# %% [markdown]
# # Make Predictions

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:10])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)

# %%
# Print out the prediction and actual labels
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:10])}")
# Out:
# Predicted classes: ['FALSE POSITIVE' 'CANDIDATE' 'FALSE POSITIVE' 'FALSE POSITIVE'
#  'FALSE POSITIVE' 'CONFIRMED' 'CANDIDATE' 'CANDIDATE' 'CANDIDATE'
#  'FALSE POSITIVE']
# Actual Labels: ['FALSE POSITIVE', 'CANDIDATE', 'FALSE POSITIVE', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'CANDIDATE', 'CANDIDATE', 'CANDIDATE', 'FALSE POSITIVE']

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Pick the features for grid search models
selected_features=df[['koi_period','koi_impact','koi_depth','koi_insol','koi_kepmag']]

# %%
# Set the X and y
data=selected_features
target=df['koi_disposition']

# %%
# Convert the y to numerical values
label_encoder = LabelEncoder()
label_encoder.fit(target)
encoded_target = label_encoder.transform(target)

# %%
# Create different train_split_test set
X_train, X_test, y_train, y_test = train_test_split(data, encoded_target,test_size=0.5, random_state=42)

# %%
X_train.head()
# Out:
#       koi_period  koi_impact  koi_depth  koi_insol  koi_kepmag
# 3021    1.450890      0.3330      135.7    1970.75      15.369
# 1972   11.191620      0.8950      166.4      88.34      14.528
# 1714    6.739683      0.6620      142.0     246.90      14.455
# 4480  310.612990      0.1879      920.0       1.43      15.503
# 5255    1.247121      1.2230      966.7     552.82      13.704

# %%
# Create the GridSearchCV model
# Support vector machine linear classifier
from sklearn.svm import SVC 
model = SVC(kernel='linear')
# Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1,5,10],
              'gamma': [0.0001, 0.001, 0.01]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................... C=1, gamma=0.0001, score=0.506, total=35.4min
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 35.4min remaining:    0.0s

# %%
print(grid.best_params_)
print(grid.best_score_)

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'first_model.sav'
joblib.dump(your_model, filename)
